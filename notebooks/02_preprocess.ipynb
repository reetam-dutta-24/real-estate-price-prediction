# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from src import preprocess

X_train, X_test, y_train, y_test = preprocess.split_data(df)
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("Columns in X:", X_train.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from src import preprocess
#       2
# ----> 3 X_train, X_test, y_train, y_test = preprocess.split_data(df)
#       4 print("X_train:", X_train.shape)
#       5 print("X_test:", X_test.shape)
#       6 print("Columns in X:", X_train.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src import preprocess

df = preprocess.load_data("C:\\Users\\dutta\\housing\\data\\raw\\kc_house_data_NaN.csv")
df = preprocess.clean_data(df)
df = preprocess.engineer_features(df)

print(df.shape)
df.head()
# Out:
# (21613, 30)
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0       3.0       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0       3.0       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0       2.0       1.00          770     10000     1.0
# 3 2014-12-09  604000.0       4.0       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0       3.0       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sale_year  sale_month  house_age  \
# 0           0     0          3  ...       2014          10         59
# 1           0     0          3  ...       2014          12         63
# 2           0     0          3  ...       2015           2         82
# 3           0     0          5  ...       2014          12         49
# 4           0     0          3  ...       2015           2         28
#
#    was_renovated  years_since_renovation  has_basement  distance_to_seattle  \
# ...

# %%
df.shape
# Out:
# (21613, 30)

# %%
df = preprocess.load_data("../data/raw/kc_house_data.csv")
print("After load:", df.shape)

df = preprocess.clean_data(df)
print("After clean:", df.shape)

df = preprocess.engineer_features(df)
print("After engineer:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = preprocess.load_data("../data/raw/kc_house_data.csv")
#       2 print("After load:", df.shape)
#       3
#       4 df = preprocess.clean_data(df)
#
# File ~\housing\src\preprocess.py:11, in load_data(path)
#      10 def load_data(path="data/raw/kc_house_data.csv"):
# ---> 11     """Load the raw King County housing dataset."""
#      12     df = pd.read_csv(path)
#      13     return df
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\dutta\housing\notebooks

# %%
df = preprocess.load_data("C:\\Users\\dutta\\housing\\data\\raw\\kc_house_data_NaN.csv")
print("After load:", df.shape)

df = preprocess.clean_data(df)
print("After clean:", df.shape)

df = preprocess.engineer_features(df)
print("After engineer:", df.shape)
# Out:
# After load: (21613, 22)
# After clean: (21613, 22)
# After engineer: (21613, 30)

# %%
import inspect
print(inspect.getsource(preprocess.engineer_features))
# Out:
# def haversine_distance(lat1, lon1, lat2, lon2):
#     R = 6371
#     lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
#     dlat = lat2 - lat1
#     dlon = lon2 - lon1
#     a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
#     c = 2 * np.arcsin(np.sqrt(a))
#     return R * c

# %%
import inspect
print(inspect.getsource(preprocess.engineer_features))
# Out:
# def haversine_distance(lat1, lon1, lat2, lon2):
#     R = 6371
#     lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
#     dlat = lat2 - lat1
#     dlon = lon2 - lon1
#     a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
#     c = 2 * np.arcsin(np.sqrt(a))
#     return R * c

# %%
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from src import preprocess

# %%
data_path = os.path.join(project_root, "data", "raw", "kc_house_data.csv")
print("Looking for file at:", data_path)
print("Exists?", os.path.exists(data_path))

df = preprocess.load_data(data_path)
print("After load:", df.shape)
# Out:
# Looking for file at: c:\Users\dutta\housing\data\raw\kc_house_data.csv
# Exists? False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 data_path = os.path.join(project_root, "data", "raw", "kc_house_data.csv")
#       2 print("Looking for file at:", data_path)
#       3 print("Exists?", os.path.exists(data_path))
#       4
# ----> 5 df = preprocess.load_data(data_path)
#       6 print("After load:", df.shape)
#
# File ~\housing\src\preprocess.py:12, in load_data(path)
#      10 def load_data(path="data/raw/kc_house_data.csv"):
#      11     """Load the raw King County housing dataset."""
# ---> 12     df = pd.read_csv(path)
#      13     return df
#
# ...

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\dutta\housing\notebooks
# ['01_eda.ipynb', '02_preprocess.ipynb']

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src import preprocess

df = preprocess.load_data("C:\\Users\\dutta\\housing\\data\\raw\\kc_house_data_NaN.csv")
print(df.shape)
# Out:
# (21613, 22)

# %%
df = preprocess.clean_data(df)
print("After clean:", df.shape)

df = preprocess.engineer_features(df)
print("After engineer:", df.shape)
# Out:
# After clean: (21613, 22)
# c:\Users\dutta\housing\src\preprocess.py:191: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['grade_x_sqft_living'] = df['grade'] * df['sqft_living']
# c:\Users\dutta\housing\src\preprocess.py:192: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['age_x_renovated'] = df['house_age'] * df['was_renovated']
# ...

# %%
df.columns.tolist()
# Out:
# ['date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15',
#  'sale_year',
#  'sale_month',
#  'house_age',
#  'was_renovated',
#  'years_since_renovation',
#  'has_basement',
#  'distance_to_seattle',
#  'sqft_ratio',
#  'bed_bath_ratio',
#  'log_price',
#  'sale_quarter',
#  'sale_day_of_week',
#  'is_peak_season',
#  'decade_built',
#  'renovation_decade',
#  'sale_month_sin',
#  'sale_month_cos',
#  'above_ratio',
#  'living_sqft_diff_from_neighbors',
#  'lot_sqft_diff_from_neighbors',
#  'total_rooms_estimate',
#  'view_binary',
#  'is_luxury',
#  'luxury_score',
#  'distance_to_bellevue',
#  'location_cluster',
#  'distance_to_seatac_airport',
#  'distance_to_boeing_field',
#  'distance_to_university_of_washington_station',
# ...

# %%
X_train, X_test, y_train, y_test = preprocess.split_data(df)
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
# Out:
# X_train: (17290, 45)
# X_test: (4323, 45)
